# %%
# The first step is uploading HIPGNN to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.3.0+cu121
# True

# %%
##Please note that the pip code for dgl should be updated according to the latest pytorch and cuda versions in colab!
# !pip install  dgl -f https://data.dgl.ai/wheels/torch-2.3/cu121/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/torch-2.3/cu121/repo.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 36.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
# !pip install torchmetrics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 17.3 MB/s eta 0:00:00
# ...

# %%
import os

# Changing the working directory
os.chdir('/content/drive/MyDrive/HIPGNN')

# %%
# !python /content/drive/MyDrive/HIPGNN/graph_prep.py --dataset STRINGdb
# Out:
# tensor([0.6410, 0.9570, 0.8170,  ..., 0.0000, 0.0000, 0.0000])

# %%
# !python /content/drive/MyDrive/HIPGNN/main_node.py --dataset STRINGdb --loss 0.01 --n_train 0.8
# Out:
# 当前日期和时间： 2024-05-22 11:24:34.932580
# Namespace(seed=42, cuda=0, dataset='STRINGdb', loss='0.01', n_train='0.8', e_train=0.8, sm=3000, lm=3000) {'nclass': 1, 'nlayer': 2, 'num_heads': 2, 'hidden_dim': 128, 'hidden_dim1': 64, 'epoch': 501, 'lr': 0.001, 'weight_decay': 1e-05, 'tran_dropout': 0.2, 'feat_dropout': 0.2, 'prop_dropout': 0.2, 'norm': 'layer', 'forward_expansion': 2}
# cuda:0
# /content/drive/MyDrive/HIPGNN/data/STRINGdb_weighted.pt
# torch.Size([13179, 1])
# 2
# 1
# n_train_ratio
# 0.8
# e_train_ratio
# 0.8
# pos_train_edge shape: (363563, 3)
# neg_train_edge shape: (363563, 3)
# 655817
# Epoch: 0, Total Loss: 0.5966, n_cla loss: 1.0471, e_pre loss: 0.6990, w_pre loss: 0.3341, Node Classification - ACC: 0.6500, AUROC: 0.6189, F1 Score: 0.5253, AUPRC: 0.3191, Link Prediction - AUROC: 0.6026, Average Precision: 0.5921, Weight Prediction - MSE: 0.3341, RMSE: 0.5780, MAE: 0.4277
# ...
